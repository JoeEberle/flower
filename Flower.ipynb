# %% [markdown]
# ![code.png](attachment:1b431264-795d-4878-8f90-22acb481036a.png)

# %%
import turtle

# %%
turtle.bgcolor("black")
turtle.speed(0)

# %%
colors = ["red","orange","green","blue"]

# %%
for x in range(170):
    for i in colors:
        turtle.color(i)
        turtle.circle(190-x, 90)
        turtle.left(90)
        turtle.circle(190-x, 90)
        turtle.left(30)
        
turtle.mainloop()

# %% [markdown]
# ![image.png](attachment:7e1dee09-51e4-49f7-b140-60bcc8f31c25.png)
